# %%
import os
import sys

# 1. Add the project root directory to the python path
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# 2. Import modules from src
from src.data.hotknots_reader import load_hotknots_file
from src.data.parse import parse_structure

# 3. Use an absolute path to the data file to avoid FileNotFoundError
data_path = os.path.join(project_root, "data", "TRA_HotKnots_max200_S80P.txt")
records, _ = load_hotknots_file(data_path)

# 4. Process and print
r = records[0]
print(r.name)
print(r.sequence)
print(r.structure)

pairs = parse_structure(r.structure)
print(f"{len(pairs)} base pairs")
print(sorted(pairs)[:5])   # first few pairs
# Out:
# PKB00240
# GGGAAAUGGACUGAGCGGCGCCGACCGCCAAACAACCGGCA
# ..............[[[[.((((.]]]]........)))).
# 8 base pairs
# [(14, 27), (15, 26), (16, 25), (17, 24), (19, 39)]
